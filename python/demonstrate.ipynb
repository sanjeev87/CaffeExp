# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Make sure that caffe is on the python path:
caffe_root = '/raid/srao/caffe_0925/'
import sys
sys.path.insert(0, caffe_root + 'python')

import caffe

plt.rcParams['figure.figsize'] = (10, 10)
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %%
net = caffe.Classifier(caffe_root + 'models/bvlc_reference_caffenet/deploy.prototxt',
                       caffe_root + 'models/bvlc_reference_caffenet/bvlc_reference_caffenet.caffemodel')
net.set_phase_test()
net.set_mode_cpu()
# input preprocessing: 'data' is the name of the input blob == net.inputs[0]
net.set_mean('data', np.load(caffe_root + 'python/caffe/imagenet/ilsvrc_2012_mean.npy'))  # ImageNet mean
net.set_raw_scale('data', 255)  # the reference model operates on images in [0,255] range instead of [0,1]
net.set_channel_swap('data', (2,1,0))  # the reference model has channels in BGR order instead of RGB

# %%
scores = net.predict([caffe.io.load_image(caffe_root + 'examples/images/cat.jpg')])

# %%
scores.shape
# Out:
# (1, 1000)

# %%
dir(net)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__instance_size__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_backward',
#  '_batch',
#  '_blob_names',
#  '_blobs',
#  '_forward',
#  '_layer_names',
#  '_set_input_arrays',
#  'backward',
#  'blobs',
#  'channel_swap',
#  'crop_dims',
#  'deprocess',
#  'forward',
#  'forward_all',
#  'forward_backward_all',
#  'image_dims',
#  'input_scale',
#  'inputs',
#  'layers',
#  'mean',
#  'outputs',
#  'params',
#  'predict',
#  'preprocess',
#  'raw_scale',
#  'reshape',
#  'save',
#  'set_channel_swap',
#  'set_device',
#  'set_input_arrays',
#  'set_input_scale',
#  'set_mean',
#  'set_mode_cpu',
#  'set_mode_gpu',
#  'set_phase_test',
#  'set_phase_train',
#  'set_raw_scale']

# %%
net.blobs
# Out:
# OrderedDict([('data', <caffe._caffe.Blob object at 0x82496d0>), ('conv1', <caffe._caffe.Blob object at 0x8249550>), ('pool1', <caffe._caffe.Blob object at 0x82492d0>), ('norm1', <caffe._caffe.Blob object at 0x7e713d0>), ('conv2', <caffe._caffe.Blob object at 0x7e71050>), ('pool2', <caffe._caffe.Blob object at 0x7e71150>), ('norm2', <caffe._caffe.Blob object at 0x7e711d0>), ('conv3', <caffe._caffe.Blob object at 0x7e71350>), ('conv4', <caffe._caffe.Blob object at 0x7e710d0>), ('conv5', <caffe._caffe.Blob object at 0x7e71250>), ('pool5', <caffe._caffe.Blob object at 0x7e715d0>), ('fc6', <caffe._caffe.Blob object at 0x7e712d0>), ('fc7', <caffe._caffe.Blob object at 0x7e71550>), ('fc8', <caffe._caffe.Blob object at 0x7e714d0>), ('prob', <caffe._caffe.Blob object at 0x7e71450>)])

# %%
net.blobs['conv1'].data.shape
# Out:
# (10, 96, 55, 55)

# %%
img = np.transpose(net.blobs['data'].data[0,:,:,:], [1,2,0]);
img2 = np.transpose(net.blobs['data'].data[1,:,:,:], [1,2,0]);
img2 == img
#img = (img-np.min(img)) / (np.max(img)-np.min(img))
# Out:
# array([[[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        ...,
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]]], dtype=bool)

# %%
plt.imshow(img)

# %%
net.blobs['conv1'].data.shape
# Out:
# (10, 96, 55, 55)

# %%
net.params
# Out:
# OrderedDict([('conv1', <caffe._caffe.BlobVec object at 0x8249e50>), ('conv2', <caffe._caffe.BlobVec object at 0x17d3750>), ('conv3', <caffe._caffe.BlobVec object at 0x27a0550>), ('conv4', <caffe._caffe.BlobVec object at 0x27a05d0>), ('conv5', <caffe._caffe.BlobVec object at 0x83ed850>), ('fc6', <caffe._caffe.BlobVec object at 0x83ed7d0>), ('fc7', <caffe._caffe.BlobVec object at 0x83ed650>), ('fc8', <caffe._caffe.BlobVec object at 0x83ed6d0>)])

# %%
net.params['conv1'][1].data.shape
# Out:
# (1, 1, 1, 96)

# %%
print dir(net.layers)
print type(net.layers)
print len(net.layers)
print net.layers[0]
# Out:
# ['__class__', '__contains__', '__delattr__', '__delitem__', '__dict__', '__doc__', '__format__', '__getattribute__', '__getitem__', '__hash__', '__init__', '__instance_size__', '__iter__', '__len__', '__module__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'append', 'extend']
# <class 'caffe._caffe.LayerVec'>
# 23
# <caffe._caffe.Layer object at 0x83e7668>

# %%
dir(net.layers[0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'blobs']

# %%
print net.layers[0].blobs[0].data.shape
print net.layers[0].blobs[1].data.shape
print type(net.params['conv1'][0].data)
# Out:
# (96, 3, 11, 11)
# (1, 1, 1, 96)
# <type 'numpy.ndarray'>

# %%
len(net.layers[0].blobs)
# Out:
# 2

# %%
net.params['conv1'][0].data == net.layers[0].blobs[0].data
# Out:
# array([[[[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]],
#
#         [[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]],
#
#         [[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]]],
#
#
#        [[[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]],
#
#         [[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]],
#
#         [[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]]],
#
#
#        [[[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]],
#
#         [[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]],
#
#         [[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]]],
#
#
#        ...,
#        [[[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]],
#
#         [[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]],
#
#         [[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]]],
#
#
#        [[[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]],
#
#         [[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]],
#
#         [[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]]],
#
#
#        [[[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]],
#
#         [[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]],
#
#         [[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]]]], dtype=bool)

# %%
net.params['conv1'][0].data
# Out:
# array([[[[ -1.21358689e-03,   3.23652686e-03,   6.70562638e-03, ...,
#            -4.04646993e-02,  -3.34104374e-02,  -2.06615720e-02],
#          [ -1.52757822e-03,   2.36130832e-03,   1.27269002e-02, ...,
#            -1.03440229e-02,  -1.29766073e-02,  -1.19824838e-02],
#          [ -1.68795008e-02,  -1.96967144e-02,  -2.78007202e-02, ...,
#             6.51425570e-02,   2.69848518e-02,   1.14041939e-02],
#          ...,
#          [  3.30793811e-03,  -1.73901021e-03,  -1.38696693e-02, ...,
#             1.15031954e-02,  -2.62027769e-03,  -3.58130375e-04],
#          [  1.63359649e-03,   3.97288101e-03,   5.48139866e-03, ...,
#             1.21502439e-02,  -1.95710847e-04,  -1.42724179e-02],
#          [ -8.25322699e-04,  -5.14897937e-03,  -5.21101989e-03, ...,
#             1.21951485e-02,   8.27158242e-03,  -9.90395527e-03]],
#
#         [[ -6.71558129e-03,   1.28365606e-02,   2.05077957e-02, ...,
#            -3.81963253e-02,  -3.59553434e-02,  -2.39658169e-02],
#          [ -1.53230457e-02,  -1.41713768e-02,   1.74819166e-03, ...,
#             1.00762118e-02,  -2.81953742e-03,  -8.80346633e-03],
#          [ -3.24621275e-02,  -4.85872999e-02,  -6.45875335e-02, ...,
